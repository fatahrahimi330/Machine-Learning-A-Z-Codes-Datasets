# %% [markdown]
# <a href="https://colab.research.google.com/github/fatahrahimi330/Machine-Learning-A-Z-Codes-Datasets/blob/main/data_preprocessing_tools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
